# %%
import pandas as pd
import numpy as np

# %%
match=pd.read_csv("DF1-matches_updated_mens_ipl-updated-WIP.csv",encoding="iso-8859-1")

# %%
match.head()
# Out:
#    matchId                  event  season Season Wise match_number  \
# 0   335982  Indian Premier League    2008                   2008-1
# 1   335983  Indian Premier League    2008                   2008-2
# 2   335984  Indian Premier League    2008                   2008-3
# 3   335986  Indian Premier League    2008                   2008-4
# 4   335985  Indian Premier League    2008                   2008-5
#
#    Total Matches outcome       Date gender                        team1  \
# 0              1     NaN  4/18/2008   male  Royal Challengers Bangalore
# 1              2     NaN  4/19/2008   male                 Punjab Kings
# 2              3     NaN  4/19/2008   male             Delhi Daredevils
# 3              4     NaN  4/20/2008   male        Kolkata Knight Riders
# 4              5     NaN  4/20/2008   male               Mumbai Indians
#
#                          team2  ... neutralvenue  \
# 0        Kolkata Knight Riders  ...          NaN
# ...

# %%
match.shape
# Out:
# (958, 29)

# %%
match.isna().sum()
# Out:
# matchId                       0
# event                         0
# season                        0
# Season Wise match_number      0
# Total Matches                 0
# outcome                     932
# Date                          0
# gender                        0
# team1                         0
# team2                         0
# toss_winner                   8
# umpire2                       6
# match_referee                 7
# reserve_umpire               30
# win_by_runs                 535
# win_by_wickets              449
# player_of_match              12
# dl_applied                    0
# date1                       956
# neutralvenue                877
# venue                         0
# method                      942
# toss_decision                 8
# city                          0
# tv_umpire                    10
# date2                       956
# winner                       26
# umpire1                       8
# eliminator                  944
# ...

# %%
match
# Out:
#      matchId                  event  season Season Wise match_number  \
# 0     335982  Indian Premier League    2008                   2008-1
# 1     335983  Indian Premier League    2008                   2008-2
# 2     335984  Indian Premier League    2008                   2008-3
# 3     335986  Indian Premier League    2008                   2008-4
# 4     335985  Indian Premier League    2008                   2008-5
# ..       ...                    ...     ...                      ...
# 953  1304116  Indian Premier League    2022                  2022-70
# 954  1312197  Indian Premier League    2022                  2022-71
# 955  1312198  Indian Premier League    2022                  2022-72
# 956  1312199  Indian Premier League    2022                  2022-73
# 957  1312200  Indian Premier League    2022                  2022-74
#
#      Total Matches outcome       Date gender                        team1  \
# ...

# %%
match.columns
# Out:
# Index(['matchId', 'event', 'season', 'Season Wise match_number',
#        'Total Matches', 'outcome', 'Date', 'gender', 'team1', 'team2',
#        'toss_winner', 'umpire2', 'match_referee', 'reserve_umpire',
#        'win_by_runs', 'win_by_wickets', 'player_of_match', 'dl_applied',
#        'date1', 'neutralvenue', 'venue', 'method', 'toss_decision', 'city',
#        'tv_umpire', 'date2', 'winner', 'umpire1', 'eliminator'],
#       dtype='object')

# %%
match['outcome'] = match['outcome'].fillna("Normal")

# %%
match['outcome'].value_counts()
# Out:
# Normal       932
# tie           14
# no result     12
# Name: outcome, dtype: int64

# %%
match
# Out:
#      matchId                  event  season Season Wise match_number  \
# 0     335982  Indian Premier League    2008                   2008-1
# 1     335983  Indian Premier League    2008                   2008-2
# 2     335984  Indian Premier League    2008                   2008-3
# 3     335986  Indian Premier League    2008                   2008-4
# 4     335985  Indian Premier League    2008                   2008-5
# ..       ...                    ...     ...                      ...
# 953  1304116  Indian Premier League    2022                  2022-70
# 954  1312197  Indian Premier League    2022                  2022-71
# 955  1312198  Indian Premier League    2022                  2022-72
# 956  1312199  Indian Premier League    2022                  2022-73
# 957  1312200  Indian Premier League    2022                  2022-74
#
#      Total Matches outcome       Date gender                        team1  \
# ...

# %%
match['toss_winner'] =match['toss_winner'].fillna("Match Abandoned")

# %%
match['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 123
# Kolkata Knight Riders          114
# Chennai Super Kings            109
# Royal Challengers Bangalore    105
# Rajasthan Royals                99
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Sunrisers Hyderabad             74
# Deccan Chargers                 43
# Delhi Capitals                  36
# Pune Warriors                   20
# Gujarat Lions                   15
# Gujarat Titans                  10
# Punjab Kings                     9
# Kochi Tuskers Kerala             8
# Match Abandoned                  8
# Rising Pune Supergiants          7
# Lucknow Super Giants             7
# Rising Pune Supergiant           6
# Name: toss_winner, dtype: int64

# %%
match['win_by_runs'] = match['win_by_runs'].fillna(0)
match['win_by_wickets'] = match['win_by_wickets'].fillna(0)

# %%
match['player_of_match'] = match['player_of_match'].fillna("Match Abandoned")

# %%
match['neutralvenue'] = match['neutralvenue'].fillna("No")

# %%
match['method'] = match['method'].fillna("Normal")

# %%
match['toss_decision'] = match['toss_decision'].fillna("Match Abandoned")

# %%
match['winner'] = match['winner'].fillna("Abandoned Match/No Results/Tie")

# %%
ballbyball=pd.read_csv("DF-3-IPL_ball_by_ball_updated-WIP-Change.csv")

# %%
ballbyball
# Out:
#         match_id  season start_date                             venue  \
# 0         335982    2008  4/18/2008             M Chinnaswamy Stadium
# 1         335982    2008  4/18/2008             M Chinnaswamy Stadium
# 2         335982    2008  4/18/2008             M Chinnaswamy Stadium
# 3         335982    2008  4/18/2008             M Chinnaswamy Stadium
# 4         335982    2008  4/18/2008             M Chinnaswamy Stadium
# ...          ...     ...        ...                               ...
# 225948   1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad
# 225949   1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad
# 225950   1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad
# 225951   1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad
# 225952   1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad
#
#         innings  over_ball  Over  ball                 batting_team  \
# ...

# %%
ballbyball.dtypes
# Out:
# match_id                    int64
# season                      int64
# start_date                 object
# venue                      object
# innings                     int64
# over_ball                 float64
# Over                        int64
# ball                        int64
# batting_team               object
# bowling_team               object
# striker                    object
# non_striker                object
# bowler                     object
# runs_off_bat                int64
# extras                      int64
# wides                     float64
# noballs                   float64
# byes                      float64
# legbyes                   float64
# penalty                   float64
# total_runs                  int64
# wicket_type                object
# player_dismissed           object
# other_wicket_type         float64
# other_player_dismissed    float64
# dtype: object

# %%
ballbyball['match_id'] = ballbyball['match_id'].astype(object)

# %%
ballbyball['innings'] = ballbyball['innings'].astype(object)

# %%
ballbyball.dtypes
# Out:
# match_id                   object
# season                      int64
# start_date                 object
# venue                      object
# innings                    object
# over_ball                 float64
# Over                        int64
# ball                        int64
# batting_team               object
# bowling_team               object
# striker                    object
# non_striker                object
# bowler                     object
# runs_off_bat                int64
# extras                      int64
# wides                     float64
# noballs                   float64
# byes                      float64
# legbyes                   float64
# penalty                   float64
# total_runs                  int64
# wicket_type                object
# player_dismissed           object
# other_wicket_type         float64
# other_player_dismissed    float64
# dtype: object

# %%
sorted_delivery = ballbyball.sort_values(by=['match_id', 'innings'])

# %%
sorted_delivery
# Out:
#        match_id  season start_date                             venue innings  \
# 29       335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# 30       335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# 31       335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# 32       335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# 33       335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# ...         ...     ...        ...                               ...     ...
# 225830  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
# 225831  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
# 225832  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
# 225833  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
# 225952  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
#
# ...

# %%
sorted_delivery.to_csv("sorted_dataset.csv", index=False)

# %%
delivery= sorted_delivery.sort_values(['match_id', 'innings','over_ball'])

# %%
delivery = delivery.reset_index(drop=True)

# %%
delivery
# Out:
#        match_id  season start_date                             venue innings  \
# 0        335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# 1        335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# 2        335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# 3        335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# 4        335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# ...         ...     ...        ...                               ...     ...
# 225948  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
# 225949  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
# 225950  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
# 225951  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
# 225952  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
#
# ...

# %%
delivery.to_csv('sorted_filename.csv',index=False)

# %%
delivery.columns
# Out:
# Index(['match_id', 'season', 'start_date', 'venue', 'innings', 'over_ball',
#        'Over', 'ball', 'batting_team', 'bowling_team', 'striker',
#        'non_striker', 'bowler', 'runs_off_bat', 'extras', 'wides', 'noballs',
#        'byes', 'legbyes', 'penalty', 'total_runs', 'wicket_type',
#        'player_dismissed', 'other_wicket_type', 'other_player_dismissed'],
#       dtype='object')

# %%
delivery['wides'] = delivery['wides'].fillna("0")
delivery['noballs'] = delivery['wides'].fillna("0")
delivery['byes'] = delivery['wides'].fillna("0")
delivery['legbyes'] = delivery['wides'].fillna("0")
delivery['penalty'] = delivery['wides'].fillna("0")

# %%
delivery
# Out:
#        match_id  season start_date                             venue innings  \
# 0        335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# 1        335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# 2        335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# 3        335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# 4        335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# ...         ...     ...        ...                               ...     ...
# 225948  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
# 225949  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
# 225950  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
# 225951  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
# 225952  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
#
# ...

# %%
delivery.dtypes
# Out:
# match_id                   object
# season                      int64
# start_date                 object
# venue                      object
# innings                    object
# over_ball                 float64
# Over                        int64
# ball                        int64
# batting_team               object
# bowling_team               object
# striker                    object
# non_striker                object
# bowler                     object
# runs_off_bat                int64
# extras                      int64
# wides                      object
# noballs                    object
# byes                       object
# legbyes                    object
# penalty                    object
# total_runs                  int64
# wicket_type                object
# player_dismissed           object
# other_wicket_type         float64
# other_player_dismissed    float64
# dtype: object

# %%
delivery['wides'] = delivery['wides'].astype(int)
delivery['noballs'] = delivery['noballs'].astype(int)
delivery['byes'] = delivery['byes'].astype(int)
delivery['legbyes'] = delivery['legbyes'].astype(int)
delivery['penalty'] = delivery['penalty'].astype(int)

# %%
delivery.dtypes
# Out:
# match_id                   object
# season                      int64
# start_date                 object
# venue                      object
# innings                    object
# over_ball                 float64
# Over                        int64
# ball                        int64
# batting_team               object
# bowling_team               object
# striker                    object
# non_striker                object
# bowler                     object
# runs_off_bat                int64
# extras                      int64
# wides                       int32
# noballs                     int32
# byes                        int32
# legbyes                     int32
# penalty                     int32
# total_runs                  int64
# wicket_type                object
# player_dismissed           object
# other_wicket_type         float64
# other_player_dismissed    float64
# dtype: object

# %%
delivery
# Out:
#        match_id  season start_date                             venue innings  \
# 0        335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# 1        335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# 2        335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# 3        335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# 4        335982    2008  4/18/2008             M Chinnaswamy Stadium       1
# ...         ...     ...        ...                               ...     ...
# 225948  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
# 225949  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
# 225950  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
# 225951  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
# 225952  1312200    2022  5/29/2022  Narendra Modi Stadium, Ahmedabad       2
#
# ...

# %%
total_score_df=delivery.groupby(["match_id",'innings']).sum()["total_runs"].reset_index()

# %%
total_score_df=total_score_df[total_score_df["innings"]==1]

# %%
match_df=match.merge(total_score_df[['match_id','total_runs']],left_on='matchId',right_on='match_id')

# %%
match_df
# Out:
#      matchId                  event  season Season Wise match_number  \
# 0     335982  Indian Premier League    2008                   2008-1
# 1     335983  Indian Premier League    2008                   2008-2
# 2     335984  Indian Premier League    2008                   2008-3
# 3     335986  Indian Premier League    2008                   2008-4
# 4     335985  Indian Premier League    2008                   2008-5
# ..       ...                    ...     ...                      ...
# 945  1304116  Indian Premier League    2022                  2022-70
# 946  1312197  Indian Premier League    2022                  2022-71
# 947  1312198  Indian Premier League    2022                  2022-72
# 948  1312199  Indian Premier League    2022                  2022-73
# 949  1312200  Indian Premier League    2022                  2022-74
#
#      Total Matches outcome       Date gender                        team1  \
# ...

# %%
match_df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Punjab Kings', 'Delhi Daredevils',
#        'Kolkata Knight Riders', 'Mumbai Indians', 'Rajasthan Royals',
#        'Deccan Chargers', 'Chennai Super Kings', 'Kochi Tuskers Kerala',
#        'Pune Warriors', 'Sunrisers Hyderabad', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Rising Pune Supergiant',
#        'Delhi Capitals', 'Lucknow Super Giants', 'Gujarat Titans'],
#       dtype=object)

# %%
teams = ['Royal Challengers Bangalore', 'Punjab Kings',
       'Kolkata Knight Riders', 'Mumbai Indians', 'Rajasthan Royals',
       'Deccan Chargers', 'Chennai Super Kings',
       'Sunrisers Hyderabad', 'Delhi Capitals', 'Lucknow Super Giants', 'Gujarat Titans']

# %%
match_df['team1'] = match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['team2'] = match_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

match_df['team1'] = match_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team2'] = match_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team2'].isin(teams)]

# %%
match_df.shape
# Out:
# (835, 31)

# %%
match_df=match_df[match_df["dl_applied"]==0]

# %%
match_df = match_df[['match_id','venue','winner','total_runs']]

# %%
delivery_df=match_df.merge(delivery,on='match_id')

# %%
delivery_df=delivery_df[delivery_df['innings'] == 2]

# %%
delivery_df
# Out:
#        match_id                                        venue_x  \
# 124      335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 125      335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 126      335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 127      335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 128      335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# ...         ...                                            ...
# 196448  1312200             Narendra Modi Stadium (Ahmedabad)
# 196449  1312200             Narendra Modi Stadium (Ahmedabad)
# 196450  1312200             Narendra Modi Stadium (Ahmedabad)
# 196451  1312200             Narendra Modi Stadium (Ahmedabad)
# 196452  1312200             Narendra Modi Stadium (Ahmedabad)
#
#                        winner  total_runs_x  season start_date  \
# 124     Kolkata Knight Riders           222    2008  4/18/2008
# 125     Kolkata Knight Riders           222    2008  4/18/2008
# ...

# %%
delivery_df.columns
# Out:
# Index(['match_id', 'venue_x', 'winner', 'total_runs_x', 'season', 'start_date',
#        'venue_y', 'innings', 'over_ball', 'Over', 'ball', 'batting_team',
#        'bowling_team', 'striker', 'non_striker', 'bowler', 'runs_off_bat',
#        'extras', 'wides', 'noballs', 'byes', 'legbyes', 'penalty',
#        'total_runs_y', 'wicket_type', 'player_dismissed', 'other_wicket_type',
#        'other_player_dismissed'],
#       dtype='object')

# %%
delivery_df.groupby('match_id').cumsum()['total_runs_y']
# Out:
# 124         1
# 125         2
# 126         2
# 127         3
# 128         4
#          ...
# 196448    124
# 196449    124
# 196450    125
# 196451    127
# 196452    133
# Name: total_runs_y, Length: 95083, dtype: int64

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
delivery_df['current_score']=delivery_df.groupby('match_id').cumsum()['total_runs_y']

# %%
delivery_df.head(1)
# Out:
#     match_id                                        venue_x  \
# 124   335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
#
#                     winner  total_runs_x  season start_date  \
# 124  Kolkata Knight Riders           222    2008  4/18/2008
#
#                    venue_y innings  over_ball  Over  ...  noballs byes  \
# 124  M Chinnaswamy Stadium       2        0.1     0  ...        0    0
#
#     legbyes penalty total_runs_y wicket_type  player_dismissed  \
# 124       0       0            1         NaN               NaN
#
#      other_wicket_type  other_player_dismissed  current_score
# 124                NaN                     NaN              1
#
# [1 rows x 29 columns]

# %%
delivery_df['runs_left'] = delivery_df['total_runs_x'] - delivery_df['current_score']

# %%
delivery_df
# Out:
#        match_id                                        venue_x  \
# 124      335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 125      335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 126      335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 127      335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 128      335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# ...         ...                                            ...
# 196448  1312200             Narendra Modi Stadium (Ahmedabad)
# 196449  1312200             Narendra Modi Stadium (Ahmedabad)
# 196450  1312200             Narendra Modi Stadium (Ahmedabad)
# 196451  1312200             Narendra Modi Stadium (Ahmedabad)
# 196452  1312200             Narendra Modi Stadium (Ahmedabad)
#
#                        winner  total_runs_x  season start_date  \
# 124     Kolkata Knight Riders           222    2008  4/18/2008
# 125     Kolkata Knight Riders           222    2008  4/18/2008
# ...

# %%
delivery_df['balls_left'] = 126 - (delivery_df['Over']*6 + delivery_df['ball'])

# %%
delivery_df
# Out:
#        match_id                                        venue_x  \
# 124      335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 125      335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 126      335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 127      335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 128      335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# ...         ...                                            ...
# 196448  1312200             Narendra Modi Stadium (Ahmedabad)
# 196449  1312200             Narendra Modi Stadium (Ahmedabad)
# 196450  1312200             Narendra Modi Stadium (Ahmedabad)
# 196451  1312200             Narendra Modi Stadium (Ahmedabad)
# 196452  1312200             Narendra Modi Stadium (Ahmedabad)
#
#                        winner  total_runs_x  season start_date  \
# 124     Kolkata Knight Riders           222    2008  4/18/2008
# 125     Kolkata Knight Riders           222    2008  4/18/2008
# ...

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna("0")
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x:x if x == "0" else "1")
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype('int')
wickets = delivery_df.groupby('match_id').cumsum()['player_dismissed'].values
delivery_df['wickets'] = 10 - wickets
delivery_df.head()
# Out:
#     match_id                                        venue_x  \
# 124   335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 125   335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 126   335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 127   335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 128   335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
#
#                     winner  total_runs_x  season start_date  \
# 124  Kolkata Knight Riders           222    2008  4/18/2008
# 125  Kolkata Knight Riders           222    2008  4/18/2008
# 126  Kolkata Knight Riders           222    2008  4/18/2008
# 127  Kolkata Knight Riders           222    2008  4/18/2008
# 128  Kolkata Knight Riders           222    2008  4/18/2008
#
#                    venue_y innings  over_ball  Over  ...  penalty  \
# 124  M Chinnaswamy Stadium       2        0.1     0  ...        0
# 125  M Chinnaswamy Stadium       2        0.2     0  ...        1
# ...

# %%
delivery_df.head()
# Out:
#     match_id                                        venue_x  \
# 124   335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 125   335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 126   335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 127   335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
# 128   335982  M Chinnaswamy Stadium (Bengaluru, Bangalore)
#
#                     winner  total_runs_x  season start_date  \
# 124  Kolkata Knight Riders           222    2008  4/18/2008
# 125  Kolkata Knight Riders           222    2008  4/18/2008
# 126  Kolkata Knight Riders           222    2008  4/18/2008
# 127  Kolkata Knight Riders           222    2008  4/18/2008
# 128  Kolkata Knight Riders           222    2008  4/18/2008
#
#                    venue_y innings  over_ball  Over  ...  penalty  \
# 124  M Chinnaswamy Stadium       2        0.1     0  ...        0
# 125  M Chinnaswamy Stadium       2        0.2     0  ...        1
# ...

# %%
delivery_df.dtypes
# Out:
# match_id                   object
# venue_x                    object
# winner                     object
# total_runs_x                int64
# season                      int64
# start_date                 object
# venue_y                    object
# innings                    object
# over_ball                 float64
# Over                        int64
# ball                        int64
# batting_team               object
# bowling_team               object
# striker                    object
# non_striker                object
# bowler                     object
# runs_off_bat                int64
# extras                      int64
# wides                       int32
# noballs                     int32
# byes                        int32
# legbyes                     int32
# penalty                     int32
# total_runs_y                int64
# wicket_type                object
# player_dismissed            int32
# other_wicket_type         float64
# ...

# %%
# crr = runs/overs
delivery_df['crr'] = (delivery_df['current_score']*6)/(120 - delivery_df['balls_left'])

# %%
delivery_df['rrr'] = (delivery_df['runs_left']*6)/delivery_df['balls_left']

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df['result'] = delivery_df.apply(result,axis=1)

# %%
final_df = delivery_df[['batting_team','bowling_team','venue_x','runs_left','balls_left','wickets','total_runs_x','crr','rrr','result']]

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample()
# Out:
#         batting_team         bowling_team                     venue_x  \
# 8455  Mumbai Indians  Chennai Super Kings  Wankhede Stadium (Mumbai)
#
#       runs_left  balls_left  wickets  total_runs_x      crr       rrr  result
# 8455         38          56        9           156  11.0625  4.071429       1

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# venue_x          0
# runs_left        0
# balls_left       0
# wickets          0
# total_runs_x     0
# crr             22
# rrr              0
# result           0
# dtype: int64

# %%
final_df.replace([np.inf,-np.inf],np.nan,inplace=True)

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team    0
# bowling_team    0
# venue_x         0
# runs_left       0
# balls_left      0
# wickets         0
# total_runs_x    0
# crr             0
# rrr             0
# result          0
# dtype: int64

# %%
X = final_df.iloc[:, : -1]
y = final_df.iloc[: , -1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state= 52)

# %%
X_train
# Out:
#                        batting_team           bowling_team  \
# 2990                Kings XI Punjab       Delhi Daredevils
# 62498              Delhi Daredevils        Kings XI Punjab
# 32528         Kolkata Knight Riders       Delhi Daredevils
# 36687   Royal Challengers Bangalore  Kolkata Knight Riders
# 148065  Royal Challengers Bangalore    Sunrisers Hyderabad
# ...                             ...                    ...
# 184330             Rajasthan Royals         Gujarat Titans
# 86405           Chennai Super Kings        Kings XI Punjab
# 35769              Delhi Daredevils  Kolkata Knight Riders
# 133518  Royal Challengers Bangalore       Rajasthan Royals
# 153655          Sunrisers Hyderabad         Mumbai Indians
#
#                                                   venue_x  runs_left  \
# 2990    Punjab Cricket Association IS Bindra Stadium (...        123
# 62498                       Arun Jaitley Stadium (Delhi)          96
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','venue_x'])
]
,remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps = [
    ('step1', trf),
    ('step2', LogisticRegression(solver = 'liblinear'))
])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team',
#                                                    'venue_x'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
X_train.describe()
# Out:
#           runs_left    balls_left       wickets  total_runs_x           crr  \
# count  75411.000000  75411.000000  75411.000000  75411.000000  75411.000000
# mean      91.421888     68.092374      7.515946    165.307939      8.789768
# std       49.563824     33.229675      2.152665     28.734744      7.455615
# min       -6.000000      3.000000      0.000000     62.000000   -126.000000
# 25%       52.000000     40.000000      6.000000    147.000000      7.185185
# 50%       91.000000     69.000000      8.000000    165.000000      8.526316
# 75%      129.000000     97.000000      9.000000    185.000000     10.071429
# max      246.000000    125.000000     10.000000    246.000000    156.000000
#
#                 rrr
# count  75411.000000
# mean       8.405277
# std        4.340228
# min       -9.000000
# 25%        6.387097
# 50%        8.024096
# 75%        9.705882
# max      114.000000

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8124966848777383

# %%
pipe.predict_proba(X_test)[10]
# Out:
# array([0.39236101, 0.60763899])

# %%
final_df.columns
# Out:
# Index(['batting_team', 'bowling_team', 'venue_x', 'runs_left', 'balls_left',
#        'wickets', 'total_runs_x', 'crr', 'rrr', 'result'],
#       dtype='object')

# %%
def match_summary(row):
    print("Batting Team-" + row['batting_team'] + " | Bowling Team-" + row['bowling_team'] + " | Target- " + str(row['total_runs_x']))

# %%
match.head()
# Out:
#    matchId                  event  season Season Wise match_number  \
# 0   335982  Indian Premier League    2008                   2008-1
# 1   335983  Indian Premier League    2008                   2008-2
# 2   335984  Indian Premier League    2008                   2008-3
# 3   335986  Indian Premier League    2008                   2008-4
# 4   335985  Indian Premier League    2008                   2008-5
#
#    Total Matches outcome       Date gender                        team1  \
# 0              1  Normal  4/18/2008   male  Royal Challengers Bangalore
# 1              2  Normal  4/19/2008   male                 Punjab Kings
# 2              3  Normal  4/19/2008   male             Delhi Daredevils
# 3              4  Normal  4/20/2008   male        Kolkata Knight Riders
# 4              5  Normal  4/20/2008   male               Mumbai Indians
#
#                          team2  ... neutralvenue  \
# 0        Kolkata Knight Riders  ...           No
# ...

# %%
def match_progression(x_df,match_id,pipe):
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team','bowling_team','venue_x','runs_left','balls_left','wickets','total_runs_x','crr','rrr']].dropna()
    temp_df = temp_df[temp_df['balls_left'] != 0]
    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)
    
    target = temp_df['total_runs_x'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wickets'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]
    
    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
temp_df,target = match_progression(delivery_df,74,pipe)
temp_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18416\3081644244.py in <module>
# ----> 1 temp_df,target = match_progression(delivery_df,74,pipe)
#       2 temp_df
#
# ~\AppData\Local\Temp\ipykernel_18416\2727519428.py in match_progression(x_df, match_id, pipe)
#       4     temp_df = match[['batting_team','bowling_team','venue_x','runs_left','balls_left','wickets','total_runs_x','crr','rrr']].dropna()
#       5     temp_df = temp_df[temp_df['balls_left'] != 0]
# ----> 6     result = pipe.predict_proba(temp_df)
#       7     temp_df['lose'] = np.round(result.T[0]*100,1)
#       8     temp_df['win'] = np.round(result.T[1]*100,1)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     111
#     112             # lambda, but not partial, allows help() to work with update_wrapper
# ...
